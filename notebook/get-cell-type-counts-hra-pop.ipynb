# %% [markdown]
# ## Code to get number of cell types for organs in sc-transcriptomics and sc-proteomics data in HRApop v1.1

# %% [markdown]
# ## Install and import libraries

# %%
# %pip install requests pandas

import requests
import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Global variables

# %%
hra_pop_version = "v1.1"

# %% [markdown]
# ## Load data

# %%
df_cts_per_as_by_t_vs_p = pd.read_csv(f"https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/main/output-data/{hra_pop_version}/reports/atlas-ad-hoc/cell-types-in-anatomical-structurescts-per-as.csv")
df_cts_per_as_by_t_vs_p = df_cts_per_as_by_t_vs_p

# %% [markdown]
# ## Analyze

# %%
df_cts_per_as_by_t_vs_p[["cell_label"]].nunique()
# Out:
# cell_label    724
# dtype: int64

# %%
df_cts_per_as_by_t_vs_p[["cell_id"]].nunique()
# Out:
# cell_id    395
# dtype: int64

# %%
df_cts_per_as_by_t_vs_p[["organ"]].nunique()
# Out:
# organ    23
# dtype: int64

# %%
tally = (
    df_cts_per_as_by_t_vs_p.groupby(["organ", "cell_label", "cell_id"])
    .size()
    .reset_index(name="n")
)
tally
# Out:
#             organ                                 cell_label  \
# 0     Left kidney                                  Adipocyte
# 1     Left kidney  Afferent / Efferent Arteriole Endothelial
# 2     Left kidney                          Airway basal cell
# 3     Left kidney                        Alveolar macrophage
# 4     Left kidney                              Amacrine cell
# ...           ...                                        ...
# 2442       uterus                                 macrophage
# 2443       uterus                           mature NK T cell
# 2444       uterus                            myometrial cell
# 2445       uterus                                   pericyte
# 2446       uterus     vascular associated smooth muscle cell
#
#                                         cell_id   n
# 0     http://purl.obolibrary.org/obo/CL_0000136   4
# 1     http://purl.obolibrary.org/obo/CL_1000412  10
# 2     http://purl.obolibrary.org/obo/CL_0002633   1
# ...
