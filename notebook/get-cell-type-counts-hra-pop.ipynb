# %% [markdown]
# ## Code to get number of cell types for organs in sc-transcriptomics and sc-proteomics data in HRApop v1.1

# %% [markdown]
# ## Install and import libraries

# %%
# %pip install requests pandas

import requests
import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Global variables

# %%
hra_pop_version = "v1.1"

# %% [markdown]
# ## Load data

# %%
df_cts_per_as = pd.read_csv(f"https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/main/output-data/{hra_pop_version}/reports/atlas-ad-hoc/cell-types-in-anatomical-structurescts-per-as.csv")
df_cts_per_as
# Out:
#         organ                                             as  \
# 0      uterus  http://purl.obolibrary.org/obo/UBERON_0000002
# 1      uterus  http://purl.obolibrary.org/obo/UBERON_0000002
# 2      uterus  http://purl.obolibrary.org/obo/UBERON_0000002
# 3      uterus  http://purl.obolibrary.org/obo/UBERON_0000002
# 4      uterus  http://purl.obolibrary.org/obo/UBERON_0000002
# ...       ...                                            ...
# 17629    lung            http://purl.org/sig/ont/fma/fma7508
# 17630    lung            http://purl.org/sig/ont/fma/fma7508
# 17631    lung            http://purl.org/sig/ont/fma/fma7508
# 17632    lung            http://purl.org/sig/ont/fma/fma7508
# 17633    lung            http://purl.org/sig/ont/fma/fma7508
#
#                                       as_label     sex               tool  \
# 0                               uterine cervix  Female  pan-human-azimuth
# 1                               uterine cervix  Female  pan-human-azimuth
# ...

# %% [markdown]
# ## Analyze

# %%
# df_cts_per_as[[""]].drop_duplicates()
